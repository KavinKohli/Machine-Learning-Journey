# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split

# %%
dataset = pd.read_csv("500hits.csv", encoding = 'latin-1')

# %%
df = pd.DataFrame(dataset)

# %%
df.head()
# Out:
#          PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0       Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1   Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2  Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3   Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4  Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
#
#      SO   SB   CS     BA  HOF
# 0   357  892  178  0.366    1
# 1   696   78   31  0.331    1
# 2   220  432  129  0.345    1
# 3  1840  358   97  0.310    1
# 4   327  722   15  0.329    1

# %%
df.shape
# Out:
# (465, 16)

# %%
X = df.drop(columns= ["PLAYER","HOF"])
y = df.HOF

# %%
X.head(6)
# Out:
#    YRS     G     AB     R     H   2B   3B   HR   RBI    BB    SO   SB   CS  \
# 0   24  3035  11434  2246  4189  724  295  117   726  1249   357  892  178
# 1   22  3026  10972  1949  3630  725  177  475  1951  1599   696   78   31
# 2   22  2789  10195  1882  3514  792  222  117   724  1381   220  432  129
# 3   20  2747  11195  1923  3465  544   66  260  1311  1082  1840  358   97
# 4   21  2792  10430  1736  3430  640  252  101     0   963   327  722   15
# 5   23  3308  11988  1816  3419  646   59  452  1844  1845  1393  168  116
#
#       BA
# 0  0.366
# 1  0.331
# 2  0.345
# 3  0.310
# 4  0.329
# 5  0.285

# %%
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: HOF, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=11, test_size=0.2)

# %%
df.head()
# Out:
#          PLAYER  YRS     G     AB     R     H   2B   3B   HR   RBI    BB  \
# 0       Ty Cobb   24  3035  11434  2246  4189  724  295  117   726  1249
# 1   Stan Musial   22  3026  10972  1949  3630  725  177  475  1951  1599
# 2  Tris Speaker   22  2789  10195  1882  3514  792  222  117   724  1381
# 3   Derek Jeter   20  2747  11195  1923  3465  544   66  260  1311  1082
# 4  Honus Wagner   21  2792  10430  1736  3430  640  252  101     0   963
#
#      SO   SB   CS     BA  HOF
# 0   357  892  178  0.366    1
# 1   696   78   31  0.331    1
# 2   220  432  129  0.345    1
# 3  1840  358   97  0.310    1
# 4   327  722   15  0.329    1

# %%
df.describe().round(3)
# Out:
#            YRS         G         AB         R         H       2B       3B  \
# count  465.000   465.000    465.000   465.000   465.000  465.000  465.000
# mean    17.049  2048.699   7511.456  1150.314  2170.247  380.953   78.555
# std      2.765   354.392   1294.066   289.635   424.191   96.483   49.363
# min     11.000  1331.000   4981.000   601.000  1660.000  177.000    3.000
# 25%     15.000  1802.000   6523.000   936.000  1838.000  312.000   41.000
# 50%     17.000  1993.000   7241.000  1104.000  2076.000  366.000   67.000
# 75%     19.000  2247.000   8180.000  1296.000  2375.000  436.000  107.000
# max     26.000  3308.000  12364.000  2295.000  4189.000  792.000  309.000
#
#             HR       RBI        BB        SO        SB       CS       BA  \
# count  465.000   465.000   465.000   465.000   465.000  465.000  465.000
# mean   201.049   894.260   783.561   847.471   195.905   58.084    0.289
# std    143.623   486.193   327.432   489.224   181.846   48.028    0.021
# ...

# %% [markdown]
# # Standardization

# %%
X1 = X.iloc[:, 0:13]
X2 = X.iloc[:, 0:13]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaleStandard = StandardScaler()

# %%
X1 = scaleStandard.fit_transform(X1)

# %%
X1 = pd.DataFrame(X1, columns=['YRS', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'SB','CS'])

# %%
X1.head()
# Out:
#         YRS         G        AB         R         H        2B        3B  \
# 0  2.516295  2.786078  3.034442  3.787062  4.764193  3.559333  4.389485
# 1  1.792237  2.760655  2.677044  2.760530  3.444971  3.569709  1.996457
# 2  1.792237  2.091184  2.075964  2.528955  3.171214  4.264876  2.909053
# 3  1.068180  1.972543  2.849554  2.670665  3.055576  1.691719 -0.254611
# 4  1.430208  2.099658  2.257758  2.024329  2.972977  2.687780  3.517449
#
#          HR       RBI        BB        SO        SB        CS
# 0 -0.585841 -0.346449  1.423013 -1.003628  3.832067  2.499511
# 1  1.909487  2.175837  2.493089 -0.309948 -0.649080 -0.564531
# 2 -0.585841 -0.350567  1.826585 -1.283965  1.299723  1.478163
# 3  0.410896  0.858071  0.912434  2.030966  0.892346  0.811161
# 4 -0.697364 -1.841290  0.548609 -1.065016  2.896201 -0.898033

# %% [markdown]
# # Normalization

# %% [markdown]
# ### This is used to converting overfitting data to fit in between 0 and 1

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scalerMinMax = MinMaxScaler(feature_range=(0,1))

# %%
X2 = scalerMinMax.fit_transform(X2)

# %%
X2 = pd.DataFrame(X2, columns=['YRS', 'G', 'AB', 'R', 'H', '2B', '3B', 'HR', 'RBI', 'BB', 'SO', 'SB','CS'])

# %%
X2.describe()
# Out:
#               YRS           G          AB           R           H          2B  \
# count  465.000000  465.000000  465.000000  465.000000  465.000000  465.000000
# mean     0.403297    0.363024    0.342741    0.324270    0.201759    0.331630
# std      0.184346    0.179257    0.175276    0.170977    0.167731    0.156884
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.266667    0.238240    0.208858    0.197757    0.070384    0.219512
# 50%      0.400000    0.334851    0.306109    0.296930    0.164492    0.307317
# 75%      0.533333    0.463328    0.433293    0.410272    0.282720    0.421138
# max      1.000000    1.000000    1.000000    1.000000    1.000000    1.000000
#
#                3B          HR         RBI          BB          SO          SB  \
# count  465.000000  465.000000  465.000000  465.000000  465.000000  465.000000
# mean     0.246911    0.257439    0.389317    0.279119    0.326327    0.135029
# ...
